# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
### 3
## (a)
#load data Q3
train3=pd.read_csv("/content/drive/MyDrive/ML/input_file/Q3test.csv")
test3=pd.read_csv("/content/drive/MyDrive/ML/input_file/Q3train.csv")

#Since there is a loss data, I get off the data
test3=test3.dropna(how='any')

X_train=train3.iloc[:,:-1].values
y_train=train3.iloc[:,-1].values
X_test=test3.iloc[:,:-1].values
y_test=test3.iloc[:,-1].values

# Scaling
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
std.fit(X_train)
X_train_scaled = std.transform(X_train)
X_test_scaled = std.transform(X_test)

# %%
from sklearn.datasets import make_regression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score

# Create a Gradient Boosting Regressor
gbr = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, random_state=42)   # With 100 estimators and learning rate 0.1
                                                                                        #

# Training
gbr.fit(X_train, y_train)

# Predict using the trained model
y_pred = gbr.predict(X_test)

# Calculate R-squared value
r2 = r2_score(y_test, y_pred)
print("R-squared value:", r2)

# Plot the original data and the predicted values
plt.scatter(X_test, y_test, color='blue', label='Original')
plt.scatter(X_test, y_pred, color='red', label='Predicted')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.title('Original vs. Predicted Values')
# Out:
# R-squared value: 0.9879039692938845
# Text(0.5, 1.0, 'Original vs. Predicted Values')

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(10, 6))
plot_tree(gbr.estimators_[0, 0], filled=True)
plt.title('Gradient Boosting Regressor - Tree 0')
plt.show()

# %%
## (b)
# For Decision tree regressor
from sklearn.tree import DecisionTreeRegressor, plot_tree

dtr = DecisionTreeRegressor(random_state=42)

dtr.fit(X_train, y_train)

r2 = r2_score(y_test, y_pred)
print("R-squared value:", r2)
# Out:
# R-squared value: 0.9879039692938845

# %%
# Plot the original data and the predicted values
plt.scatter(X_test, y_test, color='blue', label='Original')
plt.scatter(X_test, y_pred, color='red', label='Predicted')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.title('Original vs. Predicted Values')
plt.show()
